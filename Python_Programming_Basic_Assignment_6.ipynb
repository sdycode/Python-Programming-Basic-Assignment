# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Programming-Basic-Assignment/blob/main/Python_Programming_Basic_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python Program to find sum of array?

# %%
l = [5,6,8,12]
sum =0
for i in l:
  sum += i

print(sum)
# Out:
# 31

# %% [markdown]
# 2. Write a Python Program to find largest element in an array?

# %%
l = [5,6,8,12]
max  = 10 # any no
for i in l:
  if(max <i):
    max =i


print(max)
# Out:
# 12

# %% [markdown]
# 3. Write a Python Program for array rotation?

# %%
l = [5,6,8,12]
p = list(l)

def rotateBy(n):
  temp = l[0]
  for i,ind in enumerate(l):  
    p[(n+i)%4]= ind

rotateBy(2)
print(p)
# Out:
# [8, 12, 5, 6]

# %% [markdown]
# 4. Write a Python Program to Split the array and add the first part to the end?

# %%
def splitArray(arr, n, p):
	for i in range(0, p):
		x = arr[0]
		for j in range(0, n-1):
			arr[j] = arr[j + 1]
		
		arr[n-1] = x
		
arr = [20,10,85,60,41,5,75]
n = len(arr)
position = 2

splitArray(arr, n, position)

for i in range(0, n):
	print(arr[i], end = ' ')
# Out:
# 85 60 41 5 75 20 10

# %% [markdown]
# 5. Write a Python Program to check if given array is Monotonic?

# %%
def isMonotonicArray(arr):
  
    return (all(arr[i] <= arr[i + 1] for i in range(len(arr) - 1)) or
            all(arr[i] >= arr[i + 1] for i in range(len(arr) - 1)))
  

Ar = [8,5,3,1]
Br = [4,8,6,10,45]

print(isMonotonicArray(Ar))
print(isMonotonicArray(Br))
# Out:
# True
# False
